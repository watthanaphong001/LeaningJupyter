# %% [markdown]
# JupyterIPython Display

# %%
from IPython.display import IFrame, YouTubeVideo, SVG,HTML

# %% [markdown]
# Display Web Page

# %%
IFrame("https://matplotlib.org/examples/color/named_colors.html",width=800,height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://matplotlib.org/examples/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Display PDF

# %%
IFrame('http://www.fordantitrust.com/files/python.pdf',width=800,height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="http://www.fordantitrust.com/files/python.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Embed Youtube

# %%
YouTubeVideo('rHlqOqgpqag',640,360)
